# %%
# !pip install bnlp_toolkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 744.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.1 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171031 sha256=99b1af69033474287cbb1d38108c8a428e2cf5b31372b12f8ab8a6838f8408b2
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...

# %%
from bnlp import BengaliNER
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# !pip install striprtf

# %%
from striprtf.striprtf import rtf_to_text
import os

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
file_path = '/content/drive/MyDrive/final-year-project/stories/হৈমন্তী.rtf'
with open(file_path, 'r') as f:
    rtf_content = f.read()
text = rtf_to_text(rtf_content)

# %%
print(text)
# Out:
# হৈমন্তী (haimanti)
#
# কন্যার বাপ সবুর করিতে পারিতেন, কিন্তু বরের বাপ সবুর করিতে চাহিলেন না। তিনি দেখিলেন,মেয়েটির বিবাহের বয়স পার হইয়া গেছে, কিন্তু আর কিছুদিন গেলে সেটাকে ভদ্র বা অভদ্র কোনো রকমে চাপা দিবার সময়টাও পার হইয়া যাইবে। মেয়ের বয়স অবৈধ রকমে বাড়িয়া গেছে বটে, কিন্তু পণের টাকার আপেক্ষিক গুরুত্ব এখনো তাহার চেয়ে কিঞ্চিৎ উপরে আছে, সেইজন্যই তাড়া।
#
# আমি ছিলাম বর। সুতরাং, বিবাহসম্বন্ধে আমার মত যাচাই করা অনাবশ্যক ছিল। আমার কাজ আমি করিয়াছি, এফ.এ. পাস করিয়া বৃত্তি পাইয়াছি। তাই প্রজাপতির দুই পক্ষ, কন্যাপক্ষ ও বরপক্ষ ঘন ঘন বিচলিত হইয়া উঠিল।
#
# ...

# %%
from bnlp import NLTKTokenizer
bnlp_tokenizer = NLTKTokenizer()

# %%
from bnlp import CleanText

clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=False,
   remove_email=False,
   remove_emoji=False,
   remove_number=False,
   remove_digits=False,
   remove_punct=False,
   replace_with_url="<URL>",
   replace_with_email="<EMAIL>",
   replace_with_number="<NUMBER>",
   replace_with_digit="<DIGIT>",
   replace_with_punct = "<PUNC>"
)

# %%
bnltk = NLTKTokenizer()
text2 = clean_text(text)
sentence_tokens = bnltk.sentence_tokenize(text)
sentence_tokens[:5]
# Out:
# ['হৈমন্তী (haimanti)\n\nকন্যার বাপ সবুর করিতে পারিতেন, কিন্তু বরের বাপ সবুর করিতে চাহিলেন না।',
#  'তিনি দেখিলেন,মেয়েটির বিবাহের বয়স পার হইয়া গেছে, কিন্তু আর কিছুদিন গেলে সেটাকে ভদ্র বা অভদ্র কোনো রকমে চাপা দিবার সময়টাও পার হইয়া যাইবে।',
#  'মেয়ের বয়স অবৈধ রকমে বাড়িয়া গেছে বটে, কিন্তু পণের টাকার আপেক্ষিক গুরুত্ব এখনো তাহার চেয়ে কিঞ্চিৎ উপরে আছে, সেইজন্যই তাড়া।',
#  'আমি ছিলাম বর।',
#  'সুতরাং, বিবাহসম্বন্ধে আমার মত যাচাই করা অনাবশ্যক ছিল।']

# %%
word_tokens = bnltk.word_tokenize(text)
word_tokens[:10]
# Out:
# ['হৈমন্তী',
#  '(',
#  'haimanti',
#  ')',
#  'কন্যার',
#  'বাপ',
#  'সবুর',
#  'করিতে',
#  'পারিতেন',
#  ',']

# %%
from bnlp import BengaliNER
bner = BengaliNER()

# %%
bner.tag(sentence_tokens[0])
# Out:
# [('হৈমন্তী', 'O'),
#  ('haimanti', 'O'),
#  ('কন্যার', 'O'),
#  ('বাপ', 'O'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('পারিতেন', 'O'),
#  ('কিন্তু', 'O'),
#  ('বরের', 'O'),
#  ('বাপ', 'O'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('চাহিলেন', 'O'),
#  ('না', 'O')]

# %%
list = []
for sectence in sentence_tokens:
  list.append(bner.tag(sectence))

# %%
list[0]
# Out:
# [('হৈমন্তী', 'O'),
#  ('haimanti', 'O'),
#  ('কন্যার', 'O'),
#  ('বাপ', 'O'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('পারিতেন', 'O'),
#  ('কিন্তু', 'O'),
#  ('বরের', 'O'),
#  ('বাপ', 'O'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('চাহিলেন', 'O'),
#  ('না', 'O')]

# %%
count = 0
for sen in list:
  for word in sen:
    count = count + 1
print(count)
# Out:
# 3975

# %%
df = pd.read_excel("/content/drive/MyDrive/final-year-project/stories-excel-file/updated_tags/haimanti.xlsx")

# %%
df.columns = ["word", "tag"]
df.head()
# Out:
#        word    tag
# 0   হৈমন্তী      O
# 1  haimanti      O
# 2    কন্যার  S-PER
# 3       বাপ  S-PER
# 4      সবুর      O

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df['word'].to_list())
# Out:
# 3975

# %%
firstsen = sentence_tokens[0]
fsentags = bner.tag(firstsen)

# %%
fsentags
# Out:
# [('হৈমন্তী', 'O'),
#  ('haimanti', 'O'),
#  ('কন্যার', 'O'),
#  ('বাপ', 'O'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('পারিতেন', 'O'),
#  ('কিন্তু', 'O'),
#  ('বরের', 'O'),
#  ('বাপ', 'O'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('চাহিলেন', 'O'),
#  ('না', 'O')]

# %%
tuples_list = [tuple(row) for index, row in df.iterrows()]
print(tuples_list)
# Out:
# [('হৈমন্তী', 'O'), ('haimanti', 'O'), ('কন্যার', 'S-PER'), ('বাপ', 'S-PER'), ('সবুর', 'O'), ('করিতে', 'O'), ('পারিতেন', 'O'), ('কিন্তু', 'O'), ('বরের', 'S-PER'), ('বাপ', 'S-PER'), ('সবুর', 'O'), ('করিতে', 'O'), ('চাহিলেন', 'O'), ('না', 'O'), ('তিনি', 'S-PER'), ('দেখিলেন', 'O'), ('মেয়েটির', 'S-PER'), ('বিবাহের', 'O'), ('বয়স', 'O'), ('পার', 'O'), ('হইয়া', 'O'), ('গেছে', 'O'), ('কিন্তু', 'O'), ('আর', 'O'), ('কিছুদিন', 'O'), ('গেলে', 'O'), ('সেটাকে', 'O'), ('ভদ্র', 'O'), ('বা', 'O'), ('অভদ্র', 'O'), ('কোনো', 'O'), ('রকমে', 'O'), ('চাপা', 'O'), ('দিবার', 'O'), ('সময়টাও', 'O'), ('পার', 'O'), ('হইয়া', 'O'), ('যাইবে', 'O'), ('মেয়ের', 'S-PER'), ('বয়স', 'O'), ('অবৈধ', 'O'), ('রকমে', 'O'), ('বাড়িয়া', 'O'), ('গেছে', 'O'), ('বটে', 'O'), ('কিন্তু', 'O'), ('পণের', 'O'), ('টাকার', 'O'), ('আপেক্ষিক', 'O'), ('গুরুত্ব', 'O'), ('এখনো', 'O'), ('তাহার', 'O'), ('চেয়ে', 'O'), ('কিঞ্চিৎ', 'O'), ('উপরে', 'O'), ('আছে', 'O'), ('সেইজন্যই', 'O'), ('তাড়া', 'O'), ('আমি', 'S-PER'), ('ছিলাম', 'O'), ('বর', 'S-PER'), (
# ...

# %%
fsentags(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-a7ac4d267e33> in <cell line: 1>()
# ----> 1 fsentags(0)
#
# TypeError: 'list' object is not callable

# %%
count = 0
for i in range(len(fsentags)):
  if fsentags[i] == tuples_list[count]:
    count = count + 1
  else:
    fsentags[i] = tuples_list[count]

    # wrong approach
    # fsentags.insert(i, tuples_list[count])

    count = count + 1

# %%
fsentags
# Out:
# [('হৈমন্তী', 'O'),
#  ('haimanti', 'O'),
#  ('কন্যার', 'S-PER'),
#  ('বাপ', 'S-PER'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('পারিতেন', 'O'),
#  ('কিন্তু', 'O'),
#  ('বরের', 'S-PER'),
#  ('বাপ', 'S-PER'),
#  ('সবুর', 'O'),
#  ('করিতে', 'O'),
#  ('চাহিলেন', 'O'),
#  ('না', 'O')]
